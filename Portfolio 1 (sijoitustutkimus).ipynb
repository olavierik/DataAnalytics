# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.ticker import PercentFormatter

myFmt1 = PercentFormatter(xmax=1, decimals=0, symbol='%')

myFmt100 = PercentFormatter(xmax=100, decimals=0, symbol='%')

df = pd.read_excel('C://Users/mehto/Projektikansio/Rahastoraporttivalm.xlsx')

df.head()
# Out:
#                             Fund Name  10 year return  5 year return  \
# 0                       Aktia Capital        0.092656       0.068614
# 1      Danske Invest Suomen Parhaat K        0.000000       0.073917
# 2   Danske Invest Suomen Pienyhtiöt K        0.093019       0.083878
# 3           Danske Invest Suomi Osake        0.094074       0.067301
# 4  Danske Invest Suomi Osinko Plus  K        0.104553       0.082861
#
#    3 year return  1 year return  6 month return  3 month return  \
# 0       0.049454      -0.023369        0.055161       -0.032356
# 1       0.049520      -0.041219        0.001481       -0.026040
# 2       0.052164      -0.029582        0.087820       -0.049535
# 3       0.054706      -0.046504        0.028249       -0.028287
# 4       0.074205      -0.065948        0.002309       -0.042548
#
#    1 month return  1 year volatility  5 year sharpe  ...  \
# 0       -0.017644           0.141220       0.461676  ...
# ...

# %%
df.shape
# Out:
# (1350, 24)

# %%
df.columns
# Out:
# Index(['Fund Name', '10 year return', '5 year return', '3 year return',
#        '1 year return', '6 month return', '3 month return', '1 month return',
#        '1 year volatility', '5 year sharpe', '1 year sharpe', 'Duration',
#        'Management and custody fees', 'Fund Size', '1 month net subscriptions',
#        'Num Investors', 'Fund Start Date', 'Manager', 'Manager Start',
#        'Min Investment', 'YTD NET SUBSCRIPTIONS', 'Company', 'Asset Class',
#        'YTD Return'],
#       dtype='object')

# %%
df.columns = ['Fund', 'Return 10y', 'Return 5y ', 'Return 3y',
       'Return 1y', 'Return 6m', 'Return 3m ', 'Return 1m',
       'Volatility 1y', 'Sharpe 5y', 'Sharpe 1y', 'Duration',
       'Management and custody fees', 'Fund Size', '1 month net subscriptions',
       'Num Investors', 'Fund Start Date', 'Manager', 'Manager Start',
       'Min Investment', 'YTD NET SUBSCRIPTIONS', 'Company', 'Asset Class',
       'Return YTD']
df.columns
# Out:
# Index(['Fund', 'Return 10y', 'Return 5y ', 'Return 3y', 'Return 1y',
#        'Return 6m', 'Return 3m ', 'Return 1m', 'Volatility 1y', 'Sharpe 5y',
#        'Sharpe 1y', 'Duration', 'Management and custody fees', 'Fund Size',
#        '1 month net subscriptions', 'Num Investors', 'Fund Start Date',
#        'Manager', 'Manager Start', 'Min Investment', 'YTD NET SUBSCRIPTIONS',
#        'Company', 'Asset Class', 'Return YTD'],
#       dtype='object')

# %%
df.head()
# Out:
#                                  Fund  Return 10y  Return 5y   Return 3y  \
# 0                       Aktia Capital    0.092656    0.068614   0.049454
# 1      Danske Invest Suomen Parhaat K    0.000000    0.073917   0.049520
# 2   Danske Invest Suomen Pienyhtiöt K    0.093019    0.083878   0.052164
# 3           Danske Invest Suomi Osake    0.094074    0.067301   0.054706
# 4  Danske Invest Suomi Osinko Plus  K    0.104553    0.082861   0.074205
#
#    Return 1y  Return 6m  Return 3m   Return 1m  Volatility 1y  Sharpe 5y  ...  \
# 0  -0.023369   0.055161   -0.032356  -0.017644       0.141220   0.461676  ...
# 1  -0.041219   0.001481   -0.026040  -0.007884       0.128353   0.492356  ...
# 2  -0.029582   0.087820   -0.049535  -0.022505       0.133334   0.677873  ...
# 3  -0.046504   0.028249   -0.028287  -0.011662       0.128849   0.455279  ...
# 4  -0.065948   0.002309   -0.042548  -0.020453       0.136057   0.562931  ...
#
# ...

# %%
df.tail()
# Out:
#                                                    Fund  Return 10y  \
# 1345   JPM USD Ultra-Short Income UCITS ETF - USD (acc)    0.000000
# 1346  JPM USD Ultra-Short Income UCITS ETF - USD (dist)    0.000000
# 1347  JPMorgan ETFs (Ireland) ICAV - GBP Ultra-Short...    0.000000
# 1348                  Schroder ISF EURO Short Term Bond    0.012562
# 1349                                      UB Korko Plus    0.000000
#
#       Return 5y   Return 3y  Return 1y  Return 6m  Return 3m   Return 1m  \
# 1345    0.000000   0.000000   0.000000   0.000000    0.014547   0.022944
# 1346    0.000000   0.000000   0.058921   0.033996    0.007758   0.020567
# 1347    0.000000   0.000000  -0.020825  -0.039997   -0.056479  -0.020164
# 1348    0.003815   0.001417   0.008786   0.009301    0.006273   0.002195
# 1349    0.000000   0.017330   0.015353   0.018031    0.008884   0.002698
#
#       Volatility 1y  Sharpe 5y  ...  1 month net subscriptions  Num Investors  \
# ...

# %%
df.count()
# Out:
# Fund                           1350
# Return 10y                     1350
# Return 5y                      1350
# Return 3y                      1350
# Return 1y                      1350
# Return 6m                      1350
# Return 3m                      1350
# Return 1m                      1350
# Volatility 1y                  1350
# Sharpe 5y                      1350
# Sharpe 1y                      1350
# Duration                       1350
# Management and custody fees    1350
# Fund Size                      1350
# 1 month net subscriptions      1350
# Num Investors                  1350
# Fund Start Date                1350
# Manager                        1350
# Manager Start                  1350
# Min Investment                 1350
# YTD NET SUBSCRIPTIONS          1350
# Company                        1350
# Asset Class                    1350
# Return YTD                     1350
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Fund                           0
# Return 10y                     0
# Return 5y                      0
# Return 3y                      0
# Return 1y                      0
# Return 6m                      0
# Return 3m                      0
# Return 1m                      0
# Volatility 1y                  0
# Sharpe 5y                      0
# Sharpe 1y                      0
# Duration                       0
# Management and custody fees    0
# Fund Size                      0
# 1 month net subscriptions      0
# Num Investors                  0
# Fund Start Date                0
# Manager                        0
# Manager Start                  0
# Min Investment                 0
# YTD NET SUBSCRIPTIONS          0
# Company                        0
# Asset Class                    0
# Return YTD                     0
# dtype: int64

# %%
df[df['Return 10y']>0.10]
# Out:
#                                                    Fund  Return 10y  \
# 4                    Danske Invest Suomi Osinko Plus  K    0.104553
# 5                      Danske Invest Suomi Yhteisöosake    0.108556
# 7                               Evli Suomi Pienyhtiöt B    0.118633
# 12                                     Nordea Pro Suomi    0.102511
# 15                           Nordea Suomi Passiivinen I    0.119977
# 29    Seligson & Co OMX Helsinki 25 pörssinoteerattu...    0.129017
# 30                                Seligson & Co Phoebus    0.112795
# 31                 Seligson & Co Suomi Indeksirahasto A    0.113688
# 34                                         Aktia Nordic    0.113688
# 42                         eQ Pohjoismaat Pienyhtiö 2 K    0.129166
# 43                                   Evli Pohjoismaat B    0.123017
# 45                             Evli Ruotsi Pienyhtiöt B    0.177327
# 46                             Fondita Nordic Micro Cap    0.133898
# ...

# %%
df[df['Return 10y']>0.15]
# Out:
#                                                  Fund  Return 10y  Return 5y   \
# 45                           Evli Ruotsi Pienyhtiöt B    0.177327    0.113124
# 119            Danske Invest N America Enhanced Index    0.150563    0.130982
# 121                                eQ USA Indeksi 1 K    0.156984    0.143909
# 147                            OP-Amerikka Indeksi II    0.156095    0.140110
# 235                                         PYN Elite    0.199773    0.053524
# 249                  Danske Invest Kestävä Arvo Osake    0.158314    0.181631
# 305                Seligson & Co Global Top 25 Brands    0.155580    0.144516
# 312                        eQ Eurooppa Kiinteistö 1 K    0.151075    0.129866
# 316                Danske Invest Teknologia Indeksi K    0.203629    0.221341
# 319                            Danske Invest MediLife    0.151532    0.116196
# 708                       Didner & Gerge Småbolag SEK    0.173367    0.097459
# ...

# %%
df[df['Return 10y']>0.20]
# Out:
#                                    Fund  Return 10y  Return 5y   Return 3y  \
# 316  Danske Invest Teknologia Indeksi K    0.203629    0.221341   0.254158
#
#      Return 1y  Return 6m  Return 3m   Return 1m  Volatility 1y  Sharpe 5y  \
# 316   0.200811   0.218185    0.030839   0.056908       0.218266   1.152652
#
#      ...  1 month net subscriptions  Num Investors  Fund Start Date  \
# 316  ...                   4.290544           5157       1998-12-31
#
#        Manager        Manager Start  Min Investment YTD NET SUBSCRIPTIONS  \
# 316  K.Thomsen  2018-04-04 00:00:00            10.0             -3.527203
#
#                            Company         Asset Class  Return YTD
# 316  Danske Invest Rahastoyhtiö Oy  Equity Tech & Tele    0.333985
#
# [1 rows x 24 columns]

# %%
df1 = df[df['Return 10y']>0.15]

# %%
df1.head()
# Out:
#                                        Fund  Return 10y  Return 5y   \
# 45                 Evli Ruotsi Pienyhtiöt B    0.177327    0.113124
# 119  Danske Invest N America Enhanced Index    0.150563    0.130982
# 121                      eQ USA Indeksi 1 K    0.156984    0.143909
# 147                  OP-Amerikka Indeksi II    0.156095    0.140110
# 235                               PYN Elite    0.199773    0.053524
#
#      Return 3y  Return 1y  Return 6m  Return 3m   Return 1m  Volatility 1y  \
# 45    0.078146   0.077799   0.174654    0.013256  -0.021470       0.161300
# 119   0.108524   0.105136   0.129663    0.020465   0.035979       0.145822
# 121   0.124206   0.123889   0.141860    0.021036   0.036823       0.150200
# 147   0.125379   0.125487   0.143191    0.023122   0.037148       0.147968
# 235   0.048322   0.023310   0.050270    0.034135   0.022210       0.135121
#
#      Sharpe 5y  ...  1 month net subscriptions  Num Investors  \
# ...

# %%
df2 = df.groupby('Asset Class')['Return 10y'].describe()
df2
# Out:
#                              count      mean       std       min       25%  \
# Asset Class
# Alternative Hedge             24.0  0.008203  0.022603  0.000000  0.000000
# Alternative Other             52.0  0.001458  0.016390 -0.027312  0.000000
# Bond EM                       71.0  0.019100  0.028403  0.000000  0.000000
# Bond Gov Euro-zone            36.0  0.028132  0.017920  0.000000  0.010352
# Bond Gov Euro-zone_GLOBAL     19.0  0.020440  0.024442  0.000000  0.000000
# Bond IG Euro                  61.0  0.021056  0.022420  0.000000  0.000000
# Bond IG Global                50.0  0.019763  0.027419  0.000000  0.000000
# Bond non-IG Euro              25.0  0.028890  0.035521  0.000000  0.000000
# Bond non-IG Global            41.0  0.023987  0.034342  0.000000  0.000000
# Cash Fund                      7.0  0.018058  0.014984 -0.002369  0.005196
# Equity Consumer goods          4.0  0.115131  0.030250  0.081735  0.094644
# ...

# %%
sns.distplot(df['Return 10y'], bins=10)

# %%
sns.distplot(df['Return 3y'], bins=10)

# %%
sns.distplot(df['Return 1y'], bins=10)

# %%
df.corr()
# Out:
#                              Return 10y  Return 5y   Return 3y  Return 1y  \
# Return 10y                     1.000000    0.675490   0.535756   0.110123
# Return 5y                      0.675490    1.000000   0.807866   0.295936
# Return 3y                      0.535756    0.807866   1.000000   0.393895
# Return 1y                      0.110123    0.295936   0.393895   1.000000
# Return 6m                      0.329400    0.544860   0.583661   0.541265
# Return 3m                     -0.045908    0.019534   0.104463   0.748962
# Return 1m                      0.092061    0.251216   0.300017   0.621978
# Volatility 1y                  0.419677    0.559659   0.625606   0.126921
# Sharpe 5y                      0.155654    0.251078   0.151131   0.102685
# Sharpe 1y                     -0.076874   -0.029426  -0.013385   0.199141
# Duration                      -0.071430   -0.141839  -0.169970   0.078711
# Management and custody fees    0.173916    0.228764   0.286637   0.005167
# ...

# %%
df4 = df.drop(['Fund', 'Duration', '1 month net subscriptions', 'Num Investors', 'Fund Start Date',
       'Manager', 'Manager Start', 'Min Investment', 'Company', 'YTD NET SUBSCRIPTIONS'], axis=1)

# %%
df4.corr()
# Out:
#                              Return 10y  Return 5y   Return 3y  Return 1y  \
# Return 10y                     1.000000    0.675490   0.535756   0.110123
# Return 5y                      0.675490    1.000000   0.807866   0.295936
# Return 3y                      0.535756    0.807866   1.000000   0.393895
# Return 1y                      0.110123    0.295936   0.393895   1.000000
# Return 6m                      0.329400    0.544860   0.583661   0.541265
# Return 3m                     -0.045908    0.019534   0.104463   0.748962
# Return 1m                      0.092061    0.251216   0.300017   0.621978
# Volatility 1y                  0.419677    0.559659   0.625606   0.126921
# Sharpe 5y                      0.155654    0.251078   0.151131   0.102685
# Sharpe 1y                     -0.076874   -0.029426  -0.013385   0.199141
# Management and custody fees    0.173916    0.228764   0.286637   0.005167
# Fund Size                      0.069128    0.053980   0.016226   0.022209
# ...

# %%
sns.pairplot(df4, kind='reg')

# %%
df5 =df.drop(['Fund', 'Return 6m', 'Return 3m ', 'Return 1m', 'Volatility 1y', 'Sharpe 5y',
       'Sharpe 1y', 'Duration', 'Fund Size',
       '1 month net subscriptions', 'Num Investors', 'Fund Start Date',
       'Manager', 'Manager Start', 'Min Investment', 'YTD NET SUBSCRIPTIONS',
       'Company', 'Return YTD'], axis=1)

# %%
df5.corr()
# Out:
#                              Return 10y  Return 5y   Return 3y  Return 1y  \
# Return 10y                     1.000000    0.675490   0.535756   0.110123
# Return 5y                      0.675490    1.000000   0.807866   0.295936
# Return 3y                      0.535756    0.807866   1.000000   0.393895
# Return 1y                      0.110123    0.295936   0.393895   1.000000
# Management and custody fees    0.173916    0.228764   0.286637   0.005167
#
#                              Management and custody fees
# Return 10y                                      0.173916
# Return 5y                                       0.228764
# Return 3y                                       0.286637
# Return 1y                                       0.005167
# Management and custody fees                     1.000000

# %%
df6 =df.drop(['Fund', 'Return 10y', 'Return 5y ', 'Return 3y', 'Return 6m', 'Return 3m ', 'Return 1m', 'Sharpe 5y', 'Duration', 'Fund Size', '1 month net subscriptions',
       'Num Investors', 'Fund Start Date', 'Manager', 'Manager Start',
       'Min Investment', 'YTD NET SUBSCRIPTIONS', 'Company',
       'Return YTD'], axis=1)

# %%
df6.corr()
# Out:
#                              Return 1y  Volatility 1y  Sharpe 1y  \
# Return 1y                     1.000000       0.126921   0.199141
# Volatility 1y                 0.126921       1.000000  -0.224145
# Sharpe 1y                     0.199141      -0.224145   1.000000
# Management and custody fees   0.005167       0.447289  -0.082358
#
#                              Management and custody fees
# Return 1y                                       0.005167
# Volatility 1y                                   0.447289
# Sharpe 1y                                      -0.082358
# Management and custody fees                     1.000000

# %%
sns.pairplot(df6, kind='reg')

# %%
sns.jointplot(x=df['Return 10y'], y=df['Return 1y'], kind='reg')

# %%
sns.heatmap(df6.corr(), annot = True)

# %%
sns.jointplot(x=df['Management and custody fees'], y=df['Return 1y'], kind='reg')
